# %% [markdown]
# # Laptop Price Prediction using Machine Learning -:

# %% [markdown]
# ### Importing libraries :

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ### Loading data

# %%
df=pd.read_csv("laptop.csv")

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Company   TypeName Inches  \
# 0             0         0.0   Apple  Ultrabook   13.3
# 1             1         1.0   Apple  Ultrabook   13.3
# 2             2         2.0      HP   Notebook   15.6
# 3             3         3.0   Apple  Ultrabook   15.4
# 4             4         4.0   Apple  Ultrabook   13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# ...

# %%
df.shape
# Out:
# (1303, 13)

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Company', 'TypeName', 'Inches',
#        'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight',
#        'Price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0.1      1303 non-null   int64
#  1   Unnamed: 0        1273 non-null   float64
#  2   Company           1273 non-null   object
#  3   TypeName          1273 non-null   object
#  4   Inches            1273 non-null   object
#  5   ScreenResolution  1273 non-null   object
#  6   Cpu               1273 non-null   object
#  7   Ram               1273 non-null   object
#  8   Memory            1273 non-null   object
#  9   Gpu               1273 non-null   object
#  10  OpSys             1273 non-null   object
#  11  Weight            1273 non-null   object
#  12  Price             1273 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %% [markdown]
# <!-- Data Cleaning -->

# %% [markdown]
# ## Data Cleaning

# %%
df.drop(columns=["Unnamed: 0.1"],inplace=True)

# %%
df.drop(columns=["Unnamed: 0"],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName Inches                    ScreenResolution  \
# 0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook   13.3                            1440x900
# 2      HP   Notebook   15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df.isnull()
# Out:
#       Company  TypeName  Inches  ScreenResolution    Cpu    Ram  Memory  \
# 0       False     False   False             False  False  False   False
# 1       False     False   False             False  False  False   False
# 2       False     False   False             False  False  False   False
# 3       False     False   False             False  False  False   False
# 4       False     False   False             False  False  False   False
# ...       ...       ...     ...               ...    ...    ...     ...
# 1298    False     False   False             False  False  False   False
# 1299    False     False   False             False  False  False   False
# 1300    False     False   False             False  False  False   False
# 1301    False     False   False             False  False  False   False
# 1302    False     False   False             False  False  False   False
#
#         Gpu  OpSys  Weight  Price
# 0     False  False   False  False
# ...

# %%
df.isnull().sum()
# Out:
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.describe()
# Out:
#                Price
# count    1273.000000
# mean    59955.814073
# std     37332.251005
# min      9270.720000
# 25%     31914.720000
# 50%     52161.120000
# 75%     79333.387200
# max    324954.720000

# %% [markdown]
# <!-- 1>Missing values
# 2>Explore about numerical values
# 3>Explore about categorical values
# 4>Finding relationship between features -->

# %%
df.head()
# Out:
#   Company   TypeName Inches                    ScreenResolution  \
# 0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook   13.3                            1440x900
# 2      HP   Notebook   15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 29

# %%
df.shape
# Out:
# (1273, 11)

# %%
df.drop_duplicates()
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1269    Asus            Notebook   15.6
# 1270  Lenovo  2 in 1 Convertible     14
# 1271  Lenovo  2 in 1 Convertible   13.3
# 1272  Lenovo            Notebook     14
# 1273      HP            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1269                                    1366x768
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
df.shape
# Out:
# (1273, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   object
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   object
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1273 non-null   object
#  10  Price             1273 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 119.3+ KB

# %%
categorical = df.select_dtypes(include=['object']).columns
numerical=df.select_dtypes(include=['float']).columns
categorical,numerical
# Out:
# (Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#         'Memory', 'Gpu', 'OpSys', 'Weight'],
#        dtype='object'),
#  Index(['Price'], dtype='object'))

# %%
df['Inches'] = df['Inches'].astype(str)

df['Inches'] = df['Inches'].str.replace('inches', '').str.strip()

df['Inches'] = pd.to_numeric(df['Inches'], errors='coerce')

df['Inches'] = df['Inches'].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1272 non-null   float64
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   object
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1273 non-null   object
#  10  Price             1273 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 119.3+ KB

# %%
df['Ram'] = df['Ram'].astype(str)

df['Ram'] = df['Ram'].str.replace('GB', '').str.strip()

df['Ram'] = df['Ram'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1272 non-null   float64
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   int32
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1273 non-null   object
#  10  Price             1273 non-null   float64
# dtypes: float64(2), int32(1), object(8)
# memory usage: 114.4+ KB

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Weight'] = df['Weight'].astype(str)

df['Weight'] = df['Weight'].str.replace('kg', '').str.strip()

df['Weight'] = pd.to_numeric(df['Weight'], errors='coerce')

df['Weight'] = df['Weight'].astype('float32')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1272 non-null   float64
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   int32
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1272 non-null   float32
#  10  Price             1273 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 109.4+ KB

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Price Distribution plot

# %%
sns.distplot(df['Price'],color='purple')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8916\1158397349.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'],color='purple')
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(df['Inches'],color='purple')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Countplot for Categorical variables

# %%
sns.countplot(x='Company',data=df,palette='plasma')
plt.xticks(rotation=90)
plt.savefig('sales.png')
plt.show()

# %%
sns.countplot(x='TypeName',data=df,palette='plasma')
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='OpSys',data=df,palette='dark:salmon_r')
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='Ram',data=df,palette='plasma')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Price for Each laptop Company

# %%
sns.barplot(x=df["Company"],y=df["Price"],data=df,ci=None)
plt.xticks(rotation=90)
plt.savefig('company.png')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8916\3996193691.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df["Company"],y=df["Price"],data=df,ci=None)

# %% [markdown]
# ### Price for each laptop Type

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# ...

# %%
df.groupby('TypeName')['Price'].value_counts()
# Out:
# TypeName            Price
# 2 in 1 Convertible  95850.720     6
#                     79866.720     6
#                     69210.720     4
#                     53226.720     4
#                     101178.720    3
#                                  ..
# Workstation         210424.032    1
#                     83170.080     1
#                     79653.600     1
#                     72940.320     1
#                     233845.920    1
# Name: count, Length: 934, dtype: int64

# %%
sns.barplot(x=df["TypeName"],y=df["Price"],data=df,ci=None)
plt.xticks(rotation=90)
plt.savefig('typename.png')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8916\3695805098.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df["TypeName"],y=df["Price"],data=df,ci=None)

# %%
sns.barplot(x=df["OpSys"],y=df["Price"],data=df,ci=None)
plt.xticks(rotation=90)
plt.savefig('os.png')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8916\703721033.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df["OpSys"],y=df["Price"],data=df,ci=None)

# %% [markdown]
# ### Price variation for different inches of laptop

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df.head(3)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight       Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232
# 2         Intel HD Graphics 620  No OS    1.86  30636.0000

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                495
# 1366x768                                         274
# IPS Panel Full HD 1920x1080                      226
# IPS Panel Full HD / Touchscreen 1920x1080         52
# Full HD / Touchscreen 1920x1080                   45
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  14
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160                9
# 4K Ultra HD 3840x2160                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# Touchscreen 2560x1440                              6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Create a New column "Touchscreen"

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %% [markdown]
# ### Touchscreen laptop count

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# 0    1088
# 1     185
# Name: count, dtype: int64

# %%
sns.countplot(x='Touchscreen',data=df,palette='plasma')
plt.show()

# %% [markdown]
# ### Price validation for Touchscreeen laptop

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'],ci=None,palette='plasma')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8916\3281101261.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df['Touchscreen'],y=df['Price'],ci=None,palette='plasma')

# %% [markdown]
# ### Create a new column 'IPS'

# %%
df['IPS']=df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df['IPS'].value_counts()
# Out:
# IPS
# 0    914
# 1    359
# Name: count, dtype: int64

# %% [markdown]
# ### Count for IPS laptop

# %%
sns.countplot(x='IPS',data=df,palette='plasma')
plt.show()

# %% [markdown]
# ### Price validation for IPS laptop

# %%
sns.barplot(x=df['IPS'],y=df['Price'],ci=None,palette='plasma')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8916\1221722134.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df['IPS'],y=df['Price'],ci=None,palette='plasma')
# <Axes: xlabel='IPS', ylabel='Price'>

# %% [markdown]
# ### Create new columns 'x-resolution' and 'y-resolution'

# %%
new=df['ScreenResolution'].str.split('x',n=1,expand=True)
new.head()
# Out:
#                                0     1
# 0  IPS Panel Retina Display 2560  1600
# 1                           1440   900
# 2                   Full HD 1920  1080
# 3  IPS Panel Retina Display 2880  1800
# 4  IPS Panel Retina Display 2560  1600

# %%
df['X-Resolution']=new[0]
df['Y-Resolution']=new[1]
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['X-Resolution'] = df['X-Resolution'].str.replace(',','').str.findall(r'(\d+.?\d+)').apply(lambda x:x[0])
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1272 non-null   float64
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   int32
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1272 non-null   float32
#  10  Price             1273 non-null   float64
#  11  Touchscreen       1273 non-null   int64
#  12  IPS               1273 non-null   int64
#  13  X-Resolution      1273 non-null   object
#  14  Y-Resolution      1273 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# ...

# %%
df['X-Resolution'] = df['X-Resolution'].astype('int')
df['Y-Resolution'] = df['Y-Resolution'].astype('int')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1272 non-null   float64
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   int32
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1272 non-null   float32
#  10  Price             1273 non-null   float64
#  11  Touchscreen       1273 non-null   int64
#  12  IPS               1273 non-null   int64
#  13  X-Resolution      1273 non-null   int32
#  14  Y-Resolution      1273 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %% [markdown]
# ### Correlation between all the features

# %%
df_numeric = df.select_dtypes(include=['number'])
corr_matrix = df_numeric.corr()["Price"]
corr_matrix
# Out:
# Inches          0.044681
# Ram             0.685648
# Weight          0.175928
# Price           1.000000
# Touchscreen     0.188994
# IPS             0.254851
# X-Resolution    0.557556
# Y-Resolution    0.554069
# Name: Price, dtype: float64

# %% [markdown]
# #### Heatmap

# %%
df_numeric = df.select_dtypes(include=['number'])
corr_matrix = df_numeric.corr()
sns.heatmap(corr_matrix, annot=True, cmap='plasma')
plt.title("Correlation with 'Price'")
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Creating PPI Column

# %%
df["PPI"]=(((df["X-Resolution"]**2)+(df["Y-Resolution"]**2))**0.5)/df["Inches"]
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df_numeric = df.select_dtypes(include=['number'])
corr_matrix = df_numeric.corr()["Price"]
corr_matrix
# Out:
# Inches          0.044681
# Ram             0.685648
# Weight          0.175928
# Price           1.000000
# Touchscreen     0.188994
# IPS             0.254851
# X-Resolution    0.557556
# Y-Resolution    0.554069
# PPI             0.469417
# Name: Price, dtype: float64

# %%
df_numeric = df.select_dtypes(include=['number'])
corr_matrix = df_numeric.corr()
sns.heatmap(corr_matrix, annot=True, cmap='plasma')
plt.title("Correlation with 'Price'")
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Drop columns

# %%
df.drop(columns=["ScreenResolution","Inches","X-Resolution","Y-Resolution"],inplace=True)
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI
# 0  226.983005
# 1  127.677940
# ...

# %% [markdown]
# ### CPU analysis

# %%
df["Cpu"].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz     183
# Intel Core i7 7700HQ 2.8GHz    142
# Intel Core i7 7500U 2.7GHz     128
# Intel Core i7 8550U 1.8GHz      72
# Intel Core i5 8250U 1.6GHz      68
#                               ...
# AMD A9-Series 9420 2.9GHz        1
# Intel Core i7 2.2GHz             1
# AMD A6-Series 7310 2GHz          1
# Intel Atom Z8350 1.92GHz         1
# AMD E-Series 9000e 1.5GHz        1
# Name: count, Length: 118, dtype: int64

# %%
df["Cpu Name"]=df["Cpu"].apply(lambda x:" ".join(x.split()[0:3]))
df["Cpu Name"]
# Out:
# 0            Intel Core i5
# 1            Intel Core i5
# 2            Intel Core i5
# 3            Intel Core i7
# 4            Intel Core i5
#                ...
# 1298         Intel Core i7
# 1299         Intel Core i7
# 1300    Intel Celeron Dual
# 1301         Intel Core i7
# 1302    Intel Celeron Dual
# Name: Cpu Name, Length: 1273, dtype: object

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       Cpu Name
# ...

# %%
df["Cpu Name"].value_counts()
# Out:
# Cpu Name
# Intel Core i7               515
# Intel Core i5               410
# Intel Core i3               134
# Intel Celeron Dual           79
# Intel Pentium Quad           27
# Intel Core M                 19
# AMD A9-Series 9420           12
# Intel Celeron Quad            8
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# AMD A8-Series 7410            4
# Intel Atom x5-Z8350           4
# AMD Ryzen 1700                3
# Intel Atom x5-Z8550           3
# Intel Pentium Dual            3
# AMD A9-Series 9410            3
# AMD A10-Series A10-9620P      2
# Intel Xeon E3-1505M           2
# Intel Atom X5-Z8350           2
# AMD A6-Series A6-9220         2
# Intel Xeon E3-1535M           2
# AMD A9-Series A9-9420         2
# AMD A10-Series 9620P          2
# AMD E-Series 7110             2
# AMD E-Series E2-9000e         2
# AMD A10-Series 9600P          2
# AMD Ryzen 1600                1
# AMD E-Series E2-6110          1
# Intel Atom x5-Z8300           1
# ...

# %%
sns.countplot(x="Cpu Name",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
def fetch_processor(text):
    if text=="Intel Core i5" or text=="Intel Core i7" or text=="Intel Core i3":
        return text
    elif text.split()[0]=="Intel":
        return "Other Intel_Processor"
    else:
        return "AMD Processor"
df["CPU_Name"] = df["Cpu Name"].apply(lambda text:fetch_processor(text))
df["CPU_Name"]
# Out:
# 0               Intel Core i5
# 1               Intel Core i5
# 2               Intel Core i5
# 3               Intel Core i7
# 4               Intel Core i5
#                 ...
# 1298            Intel Core i7
# 1299            Intel Core i7
# 1300    Other Intel_Processor
# 1301            Intel Core i7
# 1302    Other Intel_Processor
# Name: CPU_Name, Length: 1273, dtype: object

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       Cpu Name       CPU_Name
# ...

# %%
sns.countplot(x="CPU_Name",data=df,palette="plasma")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Price analysis for CPU name using Barplot

# %%
sns.barplot(x=df["CPU_Name"],y=df["Price"],ci=None,palette="plasma")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8916\1706850270.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df["CPU_Name"],y=df["Price"],ci=None,palette="plasma")

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       Cpu Name       CPU_Name
# ...

# %%
df.drop(columns=["Cpu","Cpu Name"],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS         PPI       CPU_Name
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %% [markdown]
# ### RAM analysis

# %%
sns.countplot(x='Ram',data=df,palette='plasma')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Price vs RAM using barplot

# %%
df["Ram"].value_counts()
# Out:
# Ram
# 8     601
# 4     367
# 16    194
# 6      40
# 12     25
# 2      22
# 32     17
# 64      3
# 24      3
# 1       1
# Name: count, dtype: int64

# %%
avg_price_by_ram = df.groupby('Ram')['Price'].mean().reset_index()
avg_price_by_ram
# Out:
#    Ram          Price
# 0    1   53226.720000
# 1    2   14756.743636
# 2    4   30552.912235
# 3    6   32826.420720
# 4    8   63160.787525
# 5   12   66037.277952
# 6   16  103158.266994
# 7   24  117553.440000
# 8   32  181849.215812
# 9   64  117511.526400

# %%
sns.barplot(x=df["Ram"],y=df["Price"],ci=None,palette="plasma")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8916\2335030444.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df["Ram"],y=df["Price"],ci=None,palette="plasma")

# %% [markdown]
# ## Memory analysis

# %%
df["Memory"].value_counts()
# Out:
# Memory
# 256GB SSD                        401
# 1TB HDD                          217
# 500GB HDD                        130
# 512GB SSD                        116
# 128GB SSD +  1TB HDD              92
# 128GB SSD                         74
# 256GB SSD +  1TB HDD              71
# 32GB Flash Storage                37
# 2TB HDD                           16
# 64GB Flash Storage                14
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           13
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          4
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  500GB HDD             2
# ...

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS         PPI       CPU_Name
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df['Memory'] = df['Memory'].str.replace('GB', '')
df['Memory'] = df['Memory'].str.replace('TB', '000')
new = df['Memory'].str.split("+", n=1, expand=True)
df['first'] = new[0].str.strip()
df['Layer1HDD'] = df['first'].apply(lambda x: 1 if "HDD" in x else 0)
df['Layer1SSD'] = df['first'].apply(lambda x: 1 if "SSD" in x else 0)
df['Layer1Hybrid'] = df['first'].apply(lambda x: 1 if "Hybrid" in x else 0)
df['Layer1Flash_Storage'] = df['first'].apply(lambda x: 1 if "Flash Storage" in x else 0)
df['first'] = df['first'].str.replace(r'\D', '', regex=True)  

df['second'] = new[1].fillna('0').str.strip()
df['Layer2HDD'] = df['second'].apply(lambda x: 1 if "HDD" in x else 0)
df['Layer2SSD'] = df['second'].apply(lambda x: 1 if "SSD" in x else 0)
df['Layer2Hybrid'] = df['second'].apply(lambda x: 1 if "Hybrid" in x else 0)
df['Layer2Flash_Storage'] = df['second'].apply(lambda x: 1 if "Flash Storage" in x else 0)
df['second'] = df['second'].str.replace(r'\D', '', regex=True)  # Remove all non-numeric characters


df['first'] = df['first'].apply(lambda x: int(x) if x.isdigit() else 0)
df['second'] = df['second'].apply(lambda x: int(x) if x.isdigit() else 0)


df['HDD'] = (df['first'] * df['Layer1HDD'] + df['second'] * df['Layer2HDD'])
df['SSD'] = (df['first'] * df['Layer1SSD'] + df['second'] * df['Layer2SSD'])
df['Hybrid'] = (df['first'] * df['Layer1Hybrid'] + df['second'] * df['Layer2Hybrid'])
df['Flash_Storage'] = (df['first'] * df['Layer1Flash_Storage'] + df['second'] * df['Layer2Flash_Storage'])



df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS         PPI       CPU_Name  \
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5
#
#    HDD  SSD  Hybrid  Flash_Storage
# ...

# %%
df.drop(columns=["Memory"],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         PPI       CPU_Name  HDD  SSD  Hybrid  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128       0
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0       0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256       0
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512       0
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256       0
#
#    Flash_Storage
# 0              0
# 1            128
# ...

# %%
df_numeric = df.select_dtypes(include=['number'])
corr_matrix = df_numeric.corr()["Price"]
corr_matrix
# Out:
# Ram              0.685648
# Weight           0.175928
# Price            1.000000
# Touchscreen      0.188994
# IPS              0.254851
# PPI              0.469417
# HDD             -0.095394
# SSD              0.668416
# Hybrid           0.007843
# Flash_Storage   -0.038332
# Name: Price, dtype: float64

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Ram', 'Gpu', 'OpSys', 'Weight', 'Price',
#        'Touchscreen', 'IPS', 'PPI', 'CPU_Name', 'HDD', 'SSD', 'Hybrid',
#        'Flash_Storage'],
#       dtype='object')

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df_numeric = df.select_dtypes(include=['number'])
corr_matrix = df_numeric.corr()
sns.heatmap(corr_matrix, annot=True, cmap='plasma')
plt.title("Correlation with 'Price'")
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         PPI       CPU_Name  HDD  SSD
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256

# %% [markdown]
# ### Analysis on GPU

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      271
# Intel HD Graphics 520      181
# Intel UHD Graphics 620      66
# Nvidia GeForce GTX 1050     64
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         PPI       CPU_Name  HDD  SSD  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256
#
#   Gpu brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     703
# Nvidia    393
# AMD       176
# ARM         1
# Name: count, dtype: int64

# %%
df[df['Gpu brand']=='ARM']
# Out:
#       Company            TypeName  Ram                Gpu      OpSys  Weight  \
# 1191  Samsung  2 in 1 Convertible    4  ARM Mali T860 MP4  Chrome OS    1.15
#
#          Price  Touchscreen  IPS       PPI       CPU_Name  HDD  SSD Gpu brand
# 1191  35111.52            1    1  234.5074  AMD Processor    0    0       ARM

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         PPI       CPU_Name  HDD  SSD  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256
#
#   Gpu brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     703
# Nvidia    393
# AMD       176
# ARM         1
# Name: count, dtype: int64

# %%
sns.countplot(x='Gpu brand',data=df,palette='plasma')
# Out:
# <Axes: xlabel='Gpu brand', ylabel='count'>

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],ci=None,palette='plasma')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8916\2235859912.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df['Gpu brand'],y=df['Price'],ci=None,palette='plasma')
# <Axes: xlabel='Gpu brand', ylabel='Price'>

# %% [markdown]
# #### Remove ARM

# %%
df=df[df['Gpu brand']!='ARM']
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         PPI       CPU_Name  HDD  SSD  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256
#
#   Gpu brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],ci=None,palette='plasma')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8916\2235859912.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df['Gpu brand'],y=df['Price'],ci=None,palette='plasma')
# <Axes: xlabel='Gpu brand', ylabel='Price'>

# %%
df=df.drop(columns=['Gpu'])
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI       CPU_Name  HDD  SSD Gpu brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %% [markdown]
# ### Operating system analysis

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1047
# No OS             63
# Linux             61
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            1
# Name: count, dtype: int64

# %% [markdown]
# #### Price variation on OS in laptops

# %%
sns.barplot(x=df['OpSys'],y=df['Price'],ci=None,palette='plasma')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8916\1782540347.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df['OpSys'],y=df['Price'],ci=None,palette='plasma')

# %%
df['OpSys'].unique()
# Out:
# array(['macOS', 'No OS', 'Windows 10', 'Mac OS X', 'Linux',
#        'Windows 10 S', 'Chrome OS', 'Windows 7', 'Android'], dtype=object)

# %%
def category_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others'

# %%
df['os'] = df['OpSys'].apply(category_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI       CPU_Name  HDD  SSD Gpu brand      os
# 0  226.983005  Intel Core i5    0  128     Intel     Mac
# 1  127.677940  Intel Core i5    0    0     Intel     Mac
# 2  141.211998  Intel Core i5    0  256     Intel  Others
# 3  220.534624  Intel Core i7    0  512       AMD     Mac
# 4  226.983005  Intel Core i5    0  256     Intel     Mac

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS         PPI  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#         CPU_Name  HDD  SSD Gpu brand      os
# 0  Intel Core i5    0  128     Intel     Mac
# 1  Intel Core i5    0    0     Intel     Mac
# 2  Intel Core i5    0  256     Intel  Others
# 3  Intel Core i7    0  512       AMD     Mac
# 4  Intel Core i5    0  256     Intel     Mac

# %%
sns.countplot(x=df['os'],palette='plasma')
# Out:
# <Axes: xlabel='os', ylabel='count'>

# %%
sns.barplot(x=df['os'],y=df['Price'],ci=None,palette='plasma')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8916\1131327195.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df['os'],y=df['Price'],ci=None,palette='plasma')

# %% [markdown]
# ### Weight analysis

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS         PPI  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#         CPU_Name  HDD  SSD Gpu brand      os
# 0  Intel Core i5    0  128     Intel     Mac
# 1  Intel Core i5    0    0     Intel     Mac
# 2  Intel Core i5    0  256     Intel  Others
# 3  Intel Core i7    0  512       AMD     Mac
# 4  Intel Core i5    0  256     Intel     Mac

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8916\1125578356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df_numeric = df.select_dtypes(include=['number'])
corr_matrix = df_numeric.corr()["Price"]
corr_matrix
# Out:
# Ram            0.685521
# Weight         0.175448
# Price          1.000000
# Touchscreen    0.190738
# IPS            0.255987
# PPI            0.471335
# HDD           -0.095855
# SSD            0.668271
# Name: Price, dtype: float64

# %%
df_numeric = df.select_dtypes(include=['number'])
corr_matrix = df_numeric.corr()
sns.heatmap(corr_matrix, annot=True)
plt.title("Correlation with 'Price'")
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.savefig('sales.png')
plt.show()

# %%
sns.distplot(np.log(df['Price']))
plt.savefig('price1.png')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8916\2878569100.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.distplot(df['Price'])
plt.savefig('price.png')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8916\2614543997.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Model building

# %%
df.isnull().sum()
# Out:
# Company        0
# TypeName       0
# Ram            0
# Weight         1
# Price          0
# Touchscreen    0
# IPS            0
# PPI            1
# CPU_Name       0
# HDD            0
# SSD            0
# Gpu brand      0
# os             0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Company        0
# TypeName       0
# Ram            0
# Weight         0
# Price          0
# Touchscreen    0
# IPS            0
# PPI            0
# CPU_Name       0
# HDD            0
# SSD            0
# Gpu brand      0
# os             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 30

# %%
df.drop_duplicates()
# Out:
#      Company            TypeName  Ram  Weight        Price  Touchscreen  IPS  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1269    Asus            Notebook    4    2.20   38378.6496            0    0
# 1270  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1271  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1272  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1273      HP            Notebook    6    2.19   40705.9200            0    0
#
# ...

# %%
df.isnull().sum()
# Out:
# Company        0
# TypeName       0
# Ram            0
# Weight         0
# Price          0
# Touchscreen    0
# IPS            0
# PPI            0
# CPU_Name       0
# HDD            0
# SSD            0
# Gpu brand      0
# os             0
# dtype: int64

# %%
df.shape
# Out:
# (1270, 13)

# %%
X = df.drop(columns=['Price'],axis=1)
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPS         PPI  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1270, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPS         PPI  \
# 909       LG           Ultrabook    8    0.98            1    1  157.350512
# 414     Asus  2 in 1 Convertible    8    1.27            1    1  165.632118
# 332     Asus            Notebook    8    2.00            0    0  157.350512
# 293     Dell            Notebook    8    2.00            0    0  141.211998
# 235     Dell            Notebook   16    2.36            0    0  141.211998
# ...      ...                 ...  ...     ...          ...  ...         ...
# 480     Dell            Notebook    8    2.16            0    1  141.211998
# 309       HP            Notebook    4    1.86            0    0  141.211998
# 507     Acer            Notebook    4    2.20            0    1  141.211998
# 541     Dell            Notebook    4    1.60            0    0  157.350512
# 1224    Dell  2 in 1 Convertible    4    2.08            1    0  146.860478
#
#            CPU_Name   HDD  SSD Gpu brand       os
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor

# %%
df.head(1)
# Out:
#   Company   TypeName  Ram  Weight       Price  Touchscreen  IPS         PPI  \
# 0   Apple  Ultrabook    8    1.37  71378.6832            0    1  226.983005
#
#         CPU_Name  HDD  SSD Gpu brand   os
# 0  Intel Core i5    0  128     Intel  Mac

# %% [markdown]
# ### Linear Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('col_tnf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   [0, 1, 7, 10, 11])])),
#                 ('step2', LinearRegression())])

# %%
y_pred = pipe.predict(X_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# R2 score 0.7226407285270835
# MAE 0.2352210708701652
# MSE 0.0999757273240626

# %% [markdown]
# ### Decision Tree

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('col_tnf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   [0, 1, 7, 10, 11])])),
#                 ('step2', DecisionTreeRegressor(max_depth=8))])

# %%
y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# R2 score 0.7914442762768013
# MAE 0.20830226855744105
# MSE 0.07517509710815296

# %% [markdown]
# ### Gradient boosting

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.846521269179746
# MAE 0.1737812894902091
# MSE 0.05532228167835822

# %% [markdown]
# ### Random forest

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.834834981724753
# MAE 0.17749113427073726
# MSE 0.05953467047584281

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  Touchscreen  IPS  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
# ...
